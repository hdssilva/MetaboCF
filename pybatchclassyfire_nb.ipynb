# %% [markdown]
# ### Batch ClassyFire

# %%
from pybatchclassyfire import *
import pandas as pd
import csv
import time
import json
from pandas import json_normalize
import numpy as np
import logging
from rdkit.Chem.inchi import InchiToInchiKey
# Out:
# DEBUG:requests_cache.backends:Initializing backend: None demo_cache_pybatch
# DEBUG:requests_cache.backends.base:Initializing SQLitePickleDict with serializer: <requests_cache.serializers.pipeline.SerializerPipeline object at 0x7fd28a2a9a30>
# DEBUG:requests_cache.backends.sqlite:Opening connection to /home/hsilva/Tese/pybatchclassyfire/notebook/demo_cache_pybatch.sqlite:responses
# DEBUG:requests_cache.backends.base:Initializing SQLiteDict with serializer: <requests_cache.serializers.pipeline.SerializerPipeline object at 0x7fd28a2a9a30>
# DEBUG:requests_cache.backends.sqlite:Opening connection to /home/hsilva/Tese/pybatchclassyfire/notebook/demo_cache_pybatch.sqlite:redirects
# INFO:rdkit:Enabling RDKit 2021.03.4 jupyter extensions

# %% [markdown]
# ## Data loading

# %%
db = pd.read_pickle('~/Tese/AllDB.pkl')

# %% [markdown]
# ## Retrieve ClassyFire classifications

# %% [markdown]
# This first step is done using inchikey and interrogation of the gnps classified structures

# %%
gnps_proxy = True

# %%
url = "http://classyfire.wishartlab.com"
proxy_url =  "https://gnps-classyfire.ucsd.edu"
chunk_size = 1000
sleep_interval = 12
return_format = 'json'

# %% [markdown]
# Below is a slightly modified version of the original get_classification() which will take list object as input

# %%
logging.getLogger("urllib3").setLevel(logging.WARNING)
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("requests_cache").setLevel(logging.WARNING)

resolved_ik_number_list = [0, 0]
total_inchikey_number = len(all_inchi_keys)

while True:
    
    start_time = time.time()
    
    print('%s inchikey to resolve' % total_inchikey_number )
    get_classifications_cf_mod(all_inchi_keys, 1)
    
    cleanse('all_json.json', 'all_json.json')
    
    with open("all_json.json") as tweetfile:
        jsondic = json.loads(tweetfile.read())

    df = json_normalize(jsondic)
    df = df.drop_duplicates( 'inchikey' )
    resolved_ik_number = len( df.drop_duplicates('inchikey').inchikey )
    resolved_ik_number_list.append( resolved_ik_number )
    print('%s resolved inchikeys' % resolved_ik_number )
    print("done in --- %s seconds ---" % (time.time() - start_time))
    
    if resolved_ik_number_list[-1] < resolved_ik_number_list[-2] or resolved_ik_number_list[-1] == resolved_ik_number_list[-3]:
        break

# %% [markdown]
# We then use the cleanse function to directly remove unclassified structures from the json. Else the json file is not treated by the json_normalize() function.
# To remove null entries from json inputs and output cleaned file we define the cleanse() function. Slightly adapted from https://stackoverflow.com/a/50531943

# %%
cleanse('all_json.json', 'all_json_cleaned.json')

# %% [markdown]
# We now load this cleaned json file

# %%
with open("all_json_cleaned.json") as tweetfile:
        jsondic = json.loads(tweetfile.read())

# %% [markdown]
# And normalize the output as a dataframe

# %%
flattened_classified_json = json_normalize(jsondic)

# %% [markdown]
# And have a peak into this new df

# %%
flattened_classified_json = flattened_classified_json.drop_duplicates('inchikey')
flattened_classified_json.info()
flattened_classified_json.to_pickle('~/Tese/ClassyFire/classyfire_gnps_results.pkl')

# %% [markdown]
# ## Join classyfire results

# %% [markdown]
# Join this results with previous ones

# %%
classyfire_join = pd.read_pickle('~/Tese/ClassyFire/cf_allraw.pkl')
classyfire_join = classyfire_join.append(pd.read_pickle('~/Tese/ClassyFire/classyfire_gnps_results.pkl'))

print(classyfire_join.info())
classyfire_join = classyfire_join.dropna(how='all').drop_duplicates('inchikey').reset_index(drop=True)
classyfire_join.info()
classyfire_join.to_pickle('~/Tese/ClassyFire/cf_allraw.pkl')

# %% [markdown]
# We now want to output the unclassified InChI's

# %% [markdown]
# ## Get unclassed compounds

# %% [markdown]
# Load Database and results from classyfire

# %%
all_db = pd.read_pickle('~/Tese/AllDB.pkl')[['InChI', 'InChIKey', 'SMILES']]
all_db['InChI'] = 'InChI=' + all_db['InChI']
all_db['InChIKey'] = 'InChIKey=' + all_db['InChIKey'] 
classyfire_df = pd.read_pickle('~/Tese/ClassyFire/cf_allraw.pkl')[['inchikey', 'smiles', 'kingdom.name']]

# %% [markdown]
# Join both Dataframes by InChIKey and check for entries with no structural information

# %%
df_merged = pd.merge(all_db, classyfire_df, left_on='InChIKey', right_on='inchikey', how='left')
print(df_merged[df_merged['InChI'].isna()])

df_merged_unclassed = df_merged[df_merged['kingdom.name'].isna()].drop_duplicates('InChIKey')
df_merged_unclassed.info()
df_merged_unclassed[['InChI', 'InChIKey']].to_csv('unclassed.tsv', sep='\t', encoding="utf-8")
# Out:
# Empty DataFrame
# Columns: [InChI, InChIKey, SMILES, inchikey, smiles, kingdom.name]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 5615 to 290089
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InChI         69 non-null     object
#  1   InChIKey      69 non-null     object
#  2   SMILES        67 non-null     object
#  3   inchikey      69 non-null     object
#  4   smiles        0 non-null      object
#  5   kingdom.name  0 non-null      object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %% [markdown]
# ## Classyfing the unclassified (Post request)

# %%
query_ids = batch_query('unclassed.tsv',
                   'InChI', dialect='excel-tab')
print(query_ids)
with open('query_list.txt', 'w') as f:
    for id_ in query_ids:
        f.write(str(id_)+'\n')
# Out:
# DEBUG:requests_cache.cache_control:Cache directives from request headers: {}
# DEBUG:urllib3.connectionpool:http://classyfire.wishartlab.com:80 "POST /queries.json HTTP/1.1" 201 None
# DEBUG:requests_cache.session:Pre-cache checks for response from http://classyfire.wishartlab.com/queries.json: {'disabled cache': False, 'disabled method': True, 'disabled status': True, 'disabled by filter': False, 'disabled by headers or expiration params': False}
# DEBUG:requests_cache.session:Skipping cache write for URL: http://classyfire.wishartlab.com/queries.json
# 1 queries submitted to ClassyFire API
# [7068115]

# %%
with open('query_list.txt', 'r') as f:
    query_ids = []
    for id_ in f.readlines():
        query_ids.append(id_.strip())
query_ids
# Out:
# ['7068115']

# %% [markdown]
# The status can also be checked manually at the following adress (just change the query id)
# http://classyfire.wishartlab.com/queries/3879356.json?page=1

# %% [markdown]
# These settings of the request_cache allow to retry when 429 (or other) type of errors are returned by the classyfire server. Most of the time when too many intents are made. Since this seems to be a random behaviour, fixing a time.sleep is not safe enough.

# %%
with open("batch_query_classification.json", "w") as f:
    f.write(json.dumps(get_results_multientry_multipage_patient(query_ids, return_format="json")))

# %% [markdown]
# ## Outputs standardization
#
# Now we will standardize the json output of classyfire get_entity() and the one of get_results_multipage_patient()

# %% [markdown]
# For the output of the get_results_multipage_patient() we first load the json as a dataframe and remove identities with an empty identifier value

# %%
with open("batch_query_classification.json") as tweetfile:
    jsondic_inchi = json.loads(tweetfile.read())

# %% [markdown]
# The json_normalize function is used to flatten the nested JSON structure.
# Beware here the meta = ['id'] field can sometimes return an error. Remove if you dont need it.

# %%
normalized_df_inchi = json_normalize(jsondic_inchi,
                              record_path = 'entities',
                               meta = ['label']
                              )

# %%
normalized_df_inchi.head()
# Out:
#     identifier                                             smiles  \
# 0  Q7068026-11  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
# 1  Q7068026-12  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
# 2  Q7068026-13  CCCCCCCC\C=C\CCCCCCCC(=O)O[C@@H]1C[C@@]2(C)O[C...
# 3  Q7068026-14  CCCCCC\C=C/CCCCCCCC(=O)O[C@@H]1C[C@@]2(C)O[C@@...
# 4  Q7068026-15  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
#
#                                inchikey  \
# 0  InChIKey=XHONLVDYAICKMI-CTCVEWKCSA-N
# 1  InChIKey=RMCGPKXYXZGYBD-YXZLPVEGSA-N
# 2  InChIKey=NIJXVFJGRRKJAV-RFBZYDAGSA-N
# 3  InChIKey=FUSVDWMWPOQCIO-JPMRSYBPSA-N
# 4  InChIKey=FMGAMESTTXTHIR-FHZDASMESA-N
#
#                                   intermediate_nodes  \
# 0  [{'name': 'Carotenoids', 'description': 'Organ...
# 1  [{'name': 'Carotenoids', 'description': 'Organ...
# 2  [{'name': 'Carotenoids', 'description': 'Organ...
# 3  [{'name': 'Carotenoids', 'description': 'Organ...
# 4  [{'name': 'Carotenoids', 'description': 'Organ...
#
#                                  alternative_parents  \
# 0  [{'name': 'Oxepanes', 'description': 'Compound...
# 1  [{'name': 'Lineolic acids and derivatives', 'd...
# 2  [{'name': 'Oxepanes', 'description': 'Compound...
# 3  [{'name': 'Oxepanes', 'description': 'Compound...
# 4  [{'name': 'Lineolic acids and derivatives', 'd...
#
#                     molecular_framework  \
# 0  Aliphatic heteropolycyclic compounds
# 1  Aliphatic heteropolycyclic compounds
# 2  Aliphatic heteropolycyclic compounds
# 3  Aliphatic heteropolycyclic compounds
# 4  Aliphatic heteropolycyclic compounds
#
#                                         substituents  \
# 0  [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 1  [Xanthophyll, Octadecanoid, Oxepane, Fatty aci...
# 2  [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 3  [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 4  [Xanthophyll, Octadecanoid, Oxepane, Fatty aci...
#
#                                          description external_descriptors  \
# 0  This compound belongs to the class of organic ...                   []
# 1  This compound belongs to the class of organic ...                   []
# 2  This compound belongs to the class of organic ...                   []
# 3  This compound belongs to the class of organic ...                   []
# 4  This compound belongs to the class of organic ...                   []
#
#                                            ancestors  ...  \
# 0  [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 1  [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 2  [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 3  [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 4  [Acryloyl compounds, Alcohols and polyols, Alp...  ...
#
#                                 subclass.description subclass.chemont_id  \
# 0  Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 1  Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 2  Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 3  Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 4  Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
#
#                                         subclass.url direct_parent.name  \
# 0  http://classyfire.wishartlab.com/tax_nodes/C00...       Xanthophylls
# 1  http://classyfire.wishartlab.com/tax_nodes/C00...       Xanthophylls
# 2  http://classyfire.wishartlab.com/tax_nodes/C00...       Xanthophylls
# 3  http://classyfire.wishartlab.com/tax_nodes/C00...       Xanthophylls
# 4  http://classyfire.wishartlab.com/tax_nodes/C00...       Xanthophylls
#
#                            direct_parent.description direct_parent.chemont_id  \
# 0  Carotenoids containing an oxygenated carotene ...        CHEMONTID:0001410
# 1  Carotenoids containing an oxygenated carotene ...        CHEMONTID:0001410
# 2  Carotenoids containing an oxygenated carotene ...        CHEMONTID:0001410
# 3  Carotenoids containing an oxygenated carotene ...        CHEMONTID:0001410
# 4  Carotenoids containing an oxygenated carotene ...        CHEMONTID:0001410
#
#                                    direct_parent.url subclass report  \
# 0  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 1  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 2  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 3  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 4  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
#
#           label
# 0  pyclassyfire
# 1  pyclassyfire
# 2  pyclassyfire
# 3  pyclassyfire
# 4  pyclassyfire
#
# [5 rows x 36 columns]

# %% [markdown]
# And now we remove rows for wich no identifier is returned

# %%
normalized_df_inchi_nona = normalized_df_inchi[normalized_df_inchi['identifier'].notna()]

# %%
normalized_df_inchi_nona
# Out:
#       identifier                                             smiles  \
# 0    Q7068026-11  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
# 1    Q7068026-12  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
# 2    Q7068026-13  CCCCCCCC\C=C\CCCCCCCC(=O)O[C@@H]1C[C@@]2(C)O[C...
# 3    Q7068026-14  CCCCCC\C=C/CCCCCCCC(=O)O[C@@H]1C[C@@]2(C)O[C@@...
# 4    Q7068026-15  CCCCCC\C=C/CCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]...
# 5    Q7068026-16  CCCCCCCCCCCCCCCC(=O)O[C@H]1CC(C)(C)C(=[C@@]=C\...
# 6    Q7068026-17  CCCCCCCC\C=C\CCCCCCCC(=O)O[C@@H]1C[C@@]2(C)O[C...
# 7    Q7068026-18  [H]C(=C=C1C(C)(C)C[C@@]([H])(C[C@@]1(C)O)OC(C)...
# 8    Q7068026-19  CC(=O)O[C@H]1CC(C)(C)C(=C=C\C(C)=C\C=C\C=C\C=C...
# 9    Q7068026-20  CC[C@@H]1O[C@@H]2C[C@@H]3O[C@@H]3C[C@@H](O[C@@...
# 10  Q7068026-118  [Fe+3].[H]\C-1=C2\[N-]\C(=C([H])/C3=C(CCC([O-]...
# 13  Q7068026-121  O.O.[W++].[H][C@]1(COP(O)([O-])=O)O[C@@]2([H])...
#
#                                 inchikey  \
# 0   InChIKey=XHONLVDYAICKMI-CTCVEWKCSA-N
# 1   InChIKey=RMCGPKXYXZGYBD-YXZLPVEGSA-N
# 2   InChIKey=NIJXVFJGRRKJAV-RFBZYDAGSA-N
# 3   InChIKey=FUSVDWMWPOQCIO-JPMRSYBPSA-N
# 4   InChIKey=FMGAMESTTXTHIR-FHZDASMESA-N
# 5   InChIKey=XPOYCCSLZIKZGZ-TUWXWTLWSA-N
# 6   InChIKey=CQRZBOJKOQJRSH-PKOBTPGCSA-N
# 7   InChIKey=DYTLPXMYTFXUBJ-DOAYSRGSSA-N
# 8   InChIKey=KQQRQKINDGGYIE-SKFWEWSPSA-N
# 9   InChIKey=SNQLUCRWXUPRSU-ADULOXKHSA-N
# 10  InChIKey=JDCCRDMXPNAUND-BIEPXLGMSA-J
# 13  InChIKey=GLERWSSHJKHBIA-JSUDGWJLSA-L
#
#                                    intermediate_nodes  \
# 0   [{'name': 'Carotenoids', 'description': 'Organ...
# 1   [{'name': 'Carotenoids', 'description': 'Organ...
# 2   [{'name': 'Carotenoids', 'description': 'Organ...
# 3   [{'name': 'Carotenoids', 'description': 'Organ...
# 4   [{'name': 'Carotenoids', 'description': 'Organ...
# 5   [{'name': 'Carotenoids', 'description': 'Organ...
# 6   [{'name': 'Carotenoids', 'description': 'Organ...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 13                                                 []
#
#                                   alternative_parents  \
# 0   [{'name': 'Oxepanes', 'description': 'Compound...
# 1   [{'name': 'Lineolic acids and derivatives', 'd...
# 2   [{'name': 'Oxepanes', 'description': 'Compound...
# 3   [{'name': 'Oxepanes', 'description': 'Compound...
# 4   [{'name': 'Lineolic acids and derivatives', 'd...
# 5   [{'name': 'Oxepanes', 'description': 'Compound...
# 6   [{'name': 'Oxepanes', 'description': 'Compound...
# 7   [{'name': 'Benzofurans', 'description': 'Organ...
# 8   [{'name': 'Sesquiterpenoids', 'description': '...
# 9   [{'name': 'Vinyl bromides', 'description': 'Vi...
# 10  [{'name': 'Sesquiterpenoids', 'description': '...
# 13  [{'name': 'Secondary alkylarylamines', 'descri...
#
#                      molecular_framework  \
# 0   Aliphatic heteropolycyclic compounds
# 1   Aliphatic heteropolycyclic compounds
# 2   Aliphatic heteropolycyclic compounds
# 3   Aliphatic heteropolycyclic compounds
# 4   Aliphatic heteropolycyclic compounds
# 5   Aliphatic heteropolycyclic compounds
# 6   Aliphatic heteropolycyclic compounds
# 7   Aliphatic heteropolycyclic compounds
# 8   Aliphatic heteropolycyclic compounds
# 9   Aliphatic heteropolycyclic compounds
# 10   Aromatic heteropolycyclic compounds
# 13   Aromatic heteropolycyclic compounds
#
#                                          substituents  \
# 0   [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 1   [Xanthophyll, Octadecanoid, Oxepane, Fatty aci...
# 2   [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 3   [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 4   [Xanthophyll, Octadecanoid, Oxepane, Fatty aci...
# 5   [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 6   [Xanthophyll, Oxepane, Fatty acid ester, Fatty...
# 7   [Triterpenoid, Benzofuran, Tertiary alcohol, D...
# 8   [Terpene lactone, Cyclofarsesane sesquiterpeno...
# 9   [Oxane, Oxacycle, Vinyl halide, Vinyl bromide,...
# 10  [Metallotetrapyrrole skeleton, Farsesane sesqu...
# 13  [Pyranopterin, Secondary aliphatic/aromatic am...
#
#                                           description external_descriptors  \
# 0   This compound belongs to the class of organic ...                   []
# 1   This compound belongs to the class of organic ...                   []
# 2   This compound belongs to the class of organic ...                   []
# 3   This compound belongs to the class of organic ...                   []
# 4   This compound belongs to the class of organic ...                   []
# 5   This compound belongs to the class of organic ...                   []
# 6   This compound belongs to the class of organic ...                   []
# 7   This compound belongs to the class of organic ...                   []
# 8   This compound belongs to the class of organic ...                   []
# 9   This compound belongs to the class of organic ...                   []
# 10  This compound belongs to the class of organic ...                   []
# 13  This compound belongs to the class of organic ...                   []
#
#                                             ancestors  ...  \
# 0   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 1   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 2   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 3   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 4   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 5   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 6   [Acryloyl compounds, Alcohols and polyols, Alp...  ...
# 7   [Alcohols and polyols, Benzofurans, Carbonyl c...  ...
# 8   [Alcohols and polyols, Alpha,beta-unsaturated ...  ...
# 9                                                  []  ...
# 10                                                 []  ...
# 13  [Alkyl phosphates, Alkylthiols, Amines, Azacyc...  ...
#
#                                  subclass.description subclass.chemont_id  \
# 0   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 1   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 2   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 3   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 4   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 5   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 6   Terpenoid molecules containing 10 consecutivel...   CHEMONTID:0001554
# 7    Terpene molecules containing six isoprene units.   CHEMONTID:0001553
# 8            Prenol lipids containing a lactone ring.   CHEMONTID:0001283
# 9                                                 NaN                 NaN
# 10  Polycyclic compounds containing a tetrapyrrole...   CHEMONTID:0001926
# 13  Polycyclic aromatic compounds containing a pte...   CHEMONTID:0000110
#
#                                          subclass.url  \
# 0   http://classyfire.wishartlab.com/tax_nodes/C00...
# 1   http://classyfire.wishartlab.com/tax_nodes/C00...
# 2   http://classyfire.wishartlab.com/tax_nodes/C00...
# 3   http://classyfire.wishartlab.com/tax_nodes/C00...
# 4   http://classyfire.wishartlab.com/tax_nodes/C00...
# 5   http://classyfire.wishartlab.com/tax_nodes/C00...
# 6   http://classyfire.wishartlab.com/tax_nodes/C00...
# 7   http://classyfire.wishartlab.com/tax_nodes/C00...
# 8   http://classyfire.wishartlab.com/tax_nodes/C00...
# 9                                                 NaN
# 10  http://classyfire.wishartlab.com/tax_nodes/C00...
# 13  http://classyfire.wishartlab.com/tax_nodes/C00...
#
#                direct_parent.name  \
# 0                    Xanthophylls
# 1                    Xanthophylls
# 2                    Xanthophylls
# 3                    Xanthophylls
# 4                    Xanthophylls
# 5                    Xanthophylls
# 6                    Xanthophylls
# 7                   Triterpenoids
# 8                Terpene lactones
# 9                          Oxanes
# 10           Metallotetrapyrroles
# 13  Pyranopterins and derivatives
#
#                             direct_parent.description  \
# 0   Carotenoids containing an oxygenated carotene ...
# 1   Carotenoids containing an oxygenated carotene ...
# 2   Carotenoids containing an oxygenated carotene ...
# 3   Carotenoids containing an oxygenated carotene ...
# 4   Carotenoids containing an oxygenated carotene ...
# 5   Carotenoids containing an oxygenated carotene ...
# 6   Carotenoids containing an oxygenated carotene ...
# 7    Terpene molecules containing six isoprene units.
# 8            Prenol lipids containing a lactone ring.
# 9   Compounds containing an oxane (tetrahydropyran...
# 10  Polycyclic compounds containing a tetrapyrrole...
# 13  Pterin derivatives in which a pyran ring is fu...
#
#    direct_parent.chemont_id  \
# 0         CHEMONTID:0001410
# 1         CHEMONTID:0001410
# 2         CHEMONTID:0001410
# 3         CHEMONTID:0001410
# 4         CHEMONTID:0001410
# 5         CHEMONTID:0001410
# 6         CHEMONTID:0001410
# 7         CHEMONTID:0001553
# 8         CHEMONTID:0001283
# 9         CHEMONTID:0002012
# 10        CHEMONTID:0001926
# 13        CHEMONTID:0002263
#
#                                     direct_parent.url subclass report  \
# 0   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 1   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 2   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 3   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 4   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 5   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 6   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 7   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 8   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 9   http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 10  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
# 13  http://classyfire.wishartlab.com/tax_nodes/C00...      NaN    NaN
#
#            label
# 0   pyclassyfire
# 1   pyclassyfire
# 2   pyclassyfire
# 3   pyclassyfire
# 4   pyclassyfire
# 5   pyclassyfire
# 6   pyclassyfire
# 7   pyclassyfire
# 8   pyclassyfire
# 9   pyclassyfire
# 10  pyclassyfire
# 13  pyclassyfire
#
# [12 rows x 36 columns]

# %%
normalized_df_inchi_nona.to_pickle('~/Tese/ClassyFire/classyfire_post_results.pkl')

# %% [markdown]
# ## Join classyfire results

# %%
classyfire_join = pd.read_pickle('~/Tese/ClassyFire/cf_allraw.pkl')
classyfire_join = classyfire_join.append(pd.read_pickle('~/Tese/ClassyFire/classyfire_post_results.pkl'))
classyfire_join = classyfire_join.dropna(how='all').drop_duplicates('inchikey').reset_index(drop=True)
classyfire_join.info()
classyfire_join.to_pickle('~/Tese/ClassyFire/cf_allraw.pkl')

# %% [markdown]
# ## Get unclassed compounds

# %% [markdown]
# Load Database and results from classyfire

# %%
all_db = pd.read_pickle('~/Tese/AllDB.pkl')[['InChI', 'InChIKey', 'SMILES']]
all_db['InChI'] = 'InChI=' + all_db['InChI']
all_db['InChIKey'] = 'InChIKey=' + all_db['InChIKey'] 
classyfire_df = pd.read_pickle('~/Tese/ClassyFire/cf_allraw.pkl')[['inchikey', 'smiles', 'kingdom.name']]

# %% [markdown]
# Join both Dataframes by InChIKey and check for entries with no structural information

# %%
df_merged = pd.merge(all_db, classyfire_df, left_on='InChIKey', right_on='inchikey', how='left')
print(df_merged[df_merged['InChI'].isna()])

df_merged_unclassed = df_merged[df_merged['kingdom.name'].isna()].drop_duplicates('InChIKey')
df_merged_unclassed = df_merged_unclassed.reset_index(drop=True)
df_merged_unclassed.info()
df_merged_unclassed[['InChI', 'InChIKey']].to_csv('unclassed.tsv', sep='\t', encoding="utf-8")
# Out:
# Empty DataFrame
# Columns: [InChI, InChIKey, SMILES, inchikey, smiles, kingdom.name]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InChI         69 non-null     object
#  1   InChIKey      69 non-null     object
#  2   SMILES        67 non-null     object
#  3   inchikey      69 non-null     object
#  4   smiles        0 non-null      object
#  5   kingdom.name  0 non-null      object
# dtypes: object(6)
# memory usage: 3.4+ KB

# %% [markdown]
# ## Different Classyfire input/output InChI

# %% [markdown]
# Classyfire results are joined to the main Dataset by InChIKey. For ~400 compounds, the InChIKey in the results from Classyfire does not match with the InChIKey corresponding to the input InChI, which has the structural information.

# %%
#input
input_inchis = pd.read_csv('unclassed_nomatch.tsv', delimiter='\t', index_col=0)
input_inchis['identifier'] = input_inchis['identifier'].astype(str)

# %%
#output
cf_output = pd.read_pickle('~/Tese/ClassyFire/ik_no_match/cf_output_ik_nomatch.pkl')[['identifier', 'inchikey']]
cf_output = cf_output.rename(columns={'inchikey': 'InChIKey_output'})

# %%
adb = pd.read_pickle('~/Tese/AllDB_w_IDs.pkl')
adb['InChI'] = 'InChI=' + adb['InChI']
adb['InChIKey'] = 'InChIKey=' + adb['InChIKey']

# %%
#Is these behaviour characteristic of a specific DB? No
pd.merge(adb, input_inchis[['InChI', 'InChIKey']], on='InChIKey', how='inner').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426 entries, 0 to 425
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HMDB ID        118 non-null    object
#  1   InChI_x        426 non-null    object
#  2   InChIKey       426 non-null    object
#  3   SMILES         399 non-null    object
#  4   Lipid Maps ID  104 non-null    object
#  5   KEGG ID        40 non-null     object
#  6   ChEBI ID       213 non-null    object
#  7   InChI_y        426 non-null    object
# dtypes: object(8)
# memory usage: 30.0+ KB

# %%
corresp_ik_in_out = pd.merge(cf_output, input_inchis, on='identifier', how='inner')
corresp_ik_in_out.to_pickle('~/Tese/ClassyFire/ik_no_match/ik_corresp_in_output.pkl')
corresp_ik_in_out

# %% [markdown]
# last 7068115 query id where I couldn't retrieve any compound classification

# %%
print(len(corresp_ik_in_out))
print(len(input_inchis))

# %%
cf_output = pd.read_pickle('~/Tese/ClassyFire/ik_no_match/cf_output_ik_nomatch.pkl')
corresp_ik_in_out = pd.read_pickle('~/Tese/ClassyFire/ik_no_match/ik_corresp_in_output.pkl')[['InChIKey_output', 'InChIKey', 'InChI']]

# %%
merge = pd.merge(cf_output, corresp_ik_in_out, left_on='inchikey', right_on='InChIKey_output', how='left')
merge = merge.drop(columns=['inchikey', 'InChIKey_output', 'InChI']).rename(columns={'InChIKey':'inchikey'})
merge.to_pickle('~/Tese/ClassyFire/ik_no_match/cf_output_ik_nomatch_changed_ik.pkl')

# %% [markdown]
# Join this results to the others

# %%
classyfire_join = pd.read_pickle('~/Tese/ClassyFire/cf_allraw.pkl')
print(classyfire_join.info())
classyfire_join = classyfire_join.append(pd.read_pickle('~/Tese/ClassyFire/ik_no_match/cf_output_ik_nomatch_changed_ik.pkl'))

print(classyfire_join.info())
classyfire_join = classyfire_join.dropna(how='all').drop_duplicates('inchikey').reset_index(drop=True)
print(classyfire_join.info())
classyfire_join.to_pickle('~/Tese/ClassyFire/cf_allraw.pkl')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388251 entries, 0 to 388250
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   smiles                     388251 non-null  object
#  1   inchikey                   388250 non-null  object
#  2   intermediate_nodes         388250 non-null  object
#  3   alternative_parents        388250 non-null  object
#  4   substituents               388250 non-null  object
#  5   description                388250 non-null  object
#  6   external_descriptors       388250 non-null  object
#  7   ancestors                  388250 non-null  object
#  8   predicted_chebi_terms      388250 non-null  object
#  9   predicted_lipidmaps_terms  388250 non-null  object
#  10  classification_version     388250 non-null  object
#  11  kingdom.name               388250 non-null  object
#  12  kingdom.description        388250 non-null  object
#  13  kingdom.chemont_id         388250 non-null  object
#  14  kingdom.url                388250 non-null  object
#  15  superclass.name            388242 non-null  object
#  16  superclass.description     388242 non-null  object
#  17  superclass.chemont_id      388242 non-null  object
#  18  superclass.url             388242 non-null  object
#  19  class.name                 387707 non-null  object
#  20  class.description          387707 non-null  object
#  21  class.chemont_id           387707 non-null  object
#  22  class.url                  387707 non-null  object
#  23  direct_parent.name         388250 non-null  object
#  24  direct_parent.description  388250 non-null  object
#  25  direct_parent.chemont_id   388250 non-null  object
#  26  direct_parent.url          388250 non-null  object
#  27  molecular_framework        385462 non-null  object
#  28  subclass.name              356600 non-null  object
#  29  subclass.description       356600 non-null  object
#  30  subclass.chemont_id        356600 non-null  object
#  31  subclass.url               356600 non-null  object
#  32  identifier                 175803 non-null  object
#  33  report                     1 non-null       object
#  34  status                     0 non-null       float64
#  35  error                      0 non-null       object
#  36  subclass                   0 non-null       object
#  37  superclass                 0 non-null       float64
#  38  class                      0 non-null       float64
#  39  label                      171403 non-null  object
# dtypes: float64(3), object(37)
# memory usage: 118.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388608 entries, 0 to 356
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   smiles                     388608 non-null  object
#  1   inchikey                   388607 non-null  object
#  2   intermediate_nodes         388607 non-null  object
#  3   alternative_parents        388607 non-null  object
#  4   substituents               388607 non-null  object
#  5   description                388607 non-null  object
#  6   external_descriptors       388607 non-null  object
#  7   ancestors                  388607 non-null  object
#  8   predicted_chebi_terms      388607 non-null  object
#  9   predicted_lipidmaps_terms  388607 non-null  object
#  10  classification_version     388607 non-null  object
#  11  kingdom.name               388607 non-null  object
#  12  kingdom.description        388607 non-null  object
#  13  kingdom.chemont_id         388607 non-null  object
#  14  kingdom.url                388607 non-null  object
#  15  superclass.name            388599 non-null  object
#  16  superclass.description     388599 non-null  object
#  17  superclass.chemont_id      388599 non-null  object
#  18  superclass.url             388599 non-null  object
#  19  class.name                 388062 non-null  object
#  20  class.description          388062 non-null  object
#  21  class.chemont_id           388062 non-null  object
#  22  class.url                  388062 non-null  object
#  23  direct_parent.name         388607 non-null  object
#  24  direct_parent.description  388607 non-null  object
#  25  direct_parent.chemont_id   388607 non-null  object
#  26  direct_parent.url          388607 non-null  object
#  27  molecular_framework        385738 non-null  object
#  28  subclass.name              356906 non-null  object
#  29  subclass.description       356906 non-null  object
#  30  subclass.chemont_id        356906 non-null  object
#  31  subclass.url               356906 non-null  object
#  32  identifier                 176160 non-null  object
#  33  report                     1 non-null       object
#  34  status                     0 non-null       float64
#  35  error                      0 non-null       object
#  36  subclass                   0 non-null       object
#  37  superclass                 0 non-null       float64
#  38  class                      0 non-null       float64
#  39  label                      171722 non-null  object
# dtypes: float64(3), object(37)
# memory usage: 121.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388608 entries, 0 to 388607
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   smiles                     388608 non-null  object
#  1   inchikey                   388607 non-null  object
#  2   intermediate_nodes         388607 non-null  object
#  3   alternative_parents        388607 non-null  object
#  4   substituents               388607 non-null  object
#  5   description                388607 non-null  object
#  6   external_descriptors       388607 non-null  object
#  7   ancestors                  388607 non-null  object
#  8   predicted_chebi_terms      388607 non-null  object
#  9   predicted_lipidmaps_terms  388607 non-null  object
#  10  classification_version     388607 non-null  object
#  11  kingdom.name               388607 non-null  object
#  12  kingdom.description        388607 non-null  object
#  13  kingdom.chemont_id         388607 non-null  object
#  14  kingdom.url                388607 non-null  object
#  15  superclass.name            388599 non-null  object
#  16  superclass.description     388599 non-null  object
#  17  superclass.chemont_id      388599 non-null  object
#  18  superclass.url             388599 non-null  object
#  19  class.name                 388062 non-null  object
#  20  class.description          388062 non-null  object
#  21  class.chemont_id           388062 non-null  object
#  22  class.url                  388062 non-null  object
#  23  direct_parent.name         388607 non-null  object
#  24  direct_parent.description  388607 non-null  object
#  25  direct_parent.chemont_id   388607 non-null  object
#  26  direct_parent.url          388607 non-null  object
#  27  molecular_framework        385738 non-null  object
#  28  subclass.name              356906 non-null  object
#  29  subclass.description       356906 non-null  object
#  30  subclass.chemont_id        356906 non-null  object
#  31  subclass.url               356906 non-null  object
#  32  identifier                 176160 non-null  object
#  33  report                     1 non-null       object
#  34  status                     0 non-null       float64
#  35  error                      0 non-null       object
#  36  subclass                   0 non-null       object
#  37  superclass                 0 non-null       float64
#  38  class                      0 non-null       float64
#  39  label                      171722 non-null  object
# dtypes: float64(3), object(37)
# memory usage: 118.6+ MB
# None
